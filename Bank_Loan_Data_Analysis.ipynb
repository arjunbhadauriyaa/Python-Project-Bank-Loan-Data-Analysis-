# %% [markdown]
# # BANK LOAN ANALYSIS REPORT

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# To handle warnings 
import warnings

# %%
df=pd.read_excel(r"C:/Users/arjun/OneDrive/Desktop/Data Analyst\python files\python_Final_Project\financial_loan.xlsx")
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 4      1068350            IL       INDIVIDUAL  10+ years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL   < 1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 0                                Ryder     C           RENT 2021-02-11
# 1                       MKC Accounting     E           RENT 2021-01-01
# ...

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
df["loan_status"]
# Out:
# 0        Charged Off
# 1         Fully Paid
# 2        Charged Off
# 3         Fully Paid
# 4         Fully Paid
#             ...
# 38571        Current
# 38572        Current
# 38573        Current
# 38574        Current
# 38575        Current
# Name: loan_status, Length: 38576, dtype: object

# %%
df.tail()
# Out:
#            id address_state application_type emp_length  \
# 38571  803452            NJ       INDIVIDUAL   < 1 year
# 38572  970377            NY       INDIVIDUAL    8 years
# 38573  875376            CA       INDIVIDUAL    5 years
# 38574  972997            NY       INDIVIDUAL    5 years
# 38575  682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 38571         Joseph M Sanzari Company     C       MORTGAGE 2021-07-11
# 38572                        Swat Fame     C           RENT 2021-10-11
# 38573  Anaheim Regional Medical Center     D           RENT 2021-09-11
# 38574               Brooklyn Radiology     D           RENT 2021-10-11
# 38575                    Allen Edmonds     F           RENT 2021-07-11
#
#       last_credit_pull_date last_payment_date  ... sub_grade        term  \
# 38571            2021-05-16        2021-05-16  ...        C1   60 months
# ...

# %% [markdown]
# ## Metadata of data

# %%
print("No. of Rows:",df.shape[0])
# Out:
# No. of Rows: 38576

# %%
print("No. of Columns:",df.shape[1])
# Out:
# No. of Columns: 24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %% [markdown]
# ### Data Types

# %%
df.dtypes
# Out:
# id                                int64
# address_state                    object
# application_type                 object
# emp_length                       object
# emp_title                        object
# grade                            object
# home_ownership                   object
# issue_date               datetime64[ns]
# last_credit_pull_date    datetime64[ns]
# last_payment_date        datetime64[ns]
# loan_status                      object
# next_payment_date        datetime64[ns]
# member_id                         int64
# purpose                          object
# sub_grade                        object
# term                             object
# verification_status              object
# annual_income                   float64
# dti                             float64
# installment                     float64
# int_rate                        float64
# loan_amount                       int64
# total_acc                         int64
# ...

# %%
df.describe()
# Out:
#                  id                     issue_date  \
# count  3.857600e+04                          38576
# mean   6.810371e+05  2021-07-16 02:31:35.562007040
# min    5.473400e+04            2021-01-01 00:00:00
# 25%    5.135170e+05            2021-04-11 00:00:00
# 50%    6.627280e+05            2021-07-11 00:00:00
# 75%    8.365060e+05            2021-10-11 00:00:00
# max    1.077501e+06            2021-12-12 00:00:00
# std    2.113246e+05                            NaN
#
#                last_credit_pull_date              last_payment_date  \
# count                          38576                          38576
# mean   2021-06-08 13:36:34.193280512  2021-06-26 09:52:08.909166080
# min              2021-01-08 00:00:00            2021-01-08 00:00:00
# 25%              2021-04-15 00:00:00            2021-03-16 00:00:00
# 50%              2021-05-16 00:00:00            2021-06-14 00:00:00
# 75%              2021-08-13 00:00:00            2021-09-15 00:00:00
# ...

# %% [markdown]
# # KPI(Key Performance Indicators)

# %% [markdown]
# ### Total Loan Applications

# %%
total_loan_applications=df["id"].count()
print("Total Loan Application :",total_loan_applications)
# Out:
# Total Loan Application : 38576

# %% [markdown]
# ### Month-to-Date (MTD) Total Loan Applications

# %%
latest_issue_date=df["issue_date"].max()
latest_year=latest_issue_date.year
latest_month=latest_issue_date.month

mtd_date=df[(df["issue_date"].dt.year==latest_year)&(df["issue_date"].dt.month==latest_month)]
# mtd_date
mtd_loan_application=mtd_date["id"].count()
print(f"MTD Loan Application : {mtd_loan_application}")
# Out:
# MTD Loan Application : 4314

# %% [markdown]
# ### Total Funded Amount

# %%
total_funded_amount=df["loan_amount"].sum()
total_funded_amount_millions=total_funded_amount/1000000
print("Total Funded Amount: ${:.2f}M".format(total_funded_amount_millions))
# Out:
# Total Funded Amount: $435.76M

# %% [markdown]
# ### Month-To-Date (MTD) Total Funded Amount

# %%
latest_issue_date = df["issue_date"].max()

latest_year = latest_issue_date.year
latest_month = latest_issue_date.month

mtd_data = df[
    (df["issue_date"].dt.year == latest_year) &
    (df["issue_date"].dt.month == latest_month)
]

mtd_total_funded_amount = mtd_data["loan_amount"].sum()

mtd_total_funded_amount_millions = mtd_total_funded_amount / 1000000

print("MTD Total Funded Amount : ${:.2f}M".format(mtd_total_funded_amount_millions))
# Out:
# MTD Total Funded Amount : $53.98M

# %% [markdown]
# ### Total Amount Received

# %%
total_amount_received=df["total_payment"].sum()
total_amount_received_millions=total_amount_received/1000000
print("Total Amount Received: ${:.2f}M".format(total_amount_received_millions))
# Out:
# Total Amount Received: $473.07M

# %% [markdown]
# ### Month-To-Date (MTD) Total Amount Received

# %%
latest_issue_date = df["issue_date"].max()

latest_year = latest_issue_date.year
latest_month = latest_issue_date.month

mtd_data = df[
    (df["issue_date"].dt.year == latest_year) &
    (df["issue_date"].dt.month == latest_month)
]

mtd_total_amount_received = mtd_data["total_payment"].sum()

mtd_total_amount_received_millions = mtd_total_amount_received / 1000000

print("MTD Total Amount Received : ${:.2f}M".format(mtd_total_amount_received_millions))
# Out:
# MTD Total Amount Received : $58.07M

# %% [markdown]
# ### Average Interest Rate

# %%
average_interest_rate=df["int_rate"].mean()*100
print("Average Interest Rate:{:.2f}%.".format(average_interest_rate))
# Out:
# Average Interest Rate:12.05%.

# %% [markdown]
# ### Average Debt-to-Income Ratio(DTI)

# %%
average_dti=df["dti"].mean()*100
print("Average DTI:{:.2f}%".format(average_dti))
# Out:
# Average DTI:13.33%

# %% [markdown]
# ### Good Loan Metrics

# %%
good_loans=df[df["loan_status"].isin(["Fully Paid","Current"])]
# good_loans["loan_status"] we take data only with fully paid and current status

total_loan_applications=df["id"].count()

good_loan_applications=good_loans["id"].count()
good_loan_funded_amount=good_loans["loan_amount"].sum()
good_loan_received=good_loans["total_payment"].sum()

good_loan_funded_amount_millions=good_loan_funded_amount/1000000
good_loan_received_millions=good_loan_received/1000000

good_loan_percentage=(good_loan_applications/total_loan_applications)*100

print("Good Loan Application:",good_loan_applications)
print("Good Loan Funded Amount (in Millions):${:.2f}M".format(good_loan_funded_amount_millions))
print("Good Loan Total Received (in Millions):${:.2f}M".format(good_loan_received_millions))
print("Percentage of Good Loan Applications:${:.2f}M".format(good_loan_percentage))
# Out:
# Good Loan Application: 33243
# Good Loan Funded Amount (in Millions):$370.22M
# Good Loan Total Received (in Millions):$435.79M
# Percentage of Good Loan Applications:$86.18M

# %% [markdown]
# ### Bad Loan Matrics

# %%
bad_loans=df[df["loan_status"].isin(["Charged Off"])]
# good_loans["loan_status"] we take data only with fully paid and current status

total_loan_applications=df["id"].count()

bad_loan_applications=bad_loans["id"].count()
bad_loan_funded_amount=bad_loans["loan_amount"].sum()
bad_loan_received=bad_loans["total_payment"].sum()

bad_loan_funded_amount_millions=bad_loan_funded_amount/1000000
bad_loan_received_millions=bad_loan_received/1000000

bad_loan_percentage=(bad_loan_applications/total_loan_applications)*100

print("Bad Loan Application:",bad_loan_applications)
print("bad Loan Funded Amount (in Millions):${:.2f}M".format(bad_loan_funded_amount_millions))
print("Bad Loan Total Received (in Millions):${:.2f}M".format(bad_loan_received_millions))
print("Percentage of Bad Loan Applications:${:.2f}M".format(bad_loan_percentage))
# Out:
# Bad Loan Application: 5333
# bad Loan Funded Amount (in Millions):$65.53M
# Bad Loan Total Received (in Millions):$37.28M
# Percentage of Bad Loan Applications:$13.82M

# %% [markdown]
# ### Monthly Trends by Issue Date for total Funded Amount

# %%
monthly_funded=(
    df.sort_values("issue_date")
      .assign(month_name=lambda x: x["issue_date"].dt.strftime('%b %y'))
      .groupby("month_name",sort=False)["loan_amount"]
      .sum() 
      .div(1000000)
      .reset_index(name="loan_amount_millions")
    )

# %%
monthly_funded
# Out:
#    month_name  loan_amount_millions
# 0      Jan 21             25.031650
# 1      Feb 21             24.647825
# 2      Mar 21             28.875700
# 3      Apr 21             29.800800
# 4      May 21             31.738350
# 5      Jun 21             34.161475
# 6      Jul 21             35.813900
# 7      Aug 21             38.149600
# 8      Sep 21             40.907725
# 9      Oct 21             44.893800
# 10     Nov 21             47.754825
# 11     Dec 21             53.981425

# %%
plt.figure(figsize=(12,6))
# Plot for the area
plt.fill_between(monthly_funded["month_name"],monthly_funded["loan_amount_millions"],color="lightgreen",alpha=0.5)
# Plot for the Line
plt.plot(monthly_funded["month_name"],monthly_funded["loan_amount_millions"],color="orange",linewidth=2)


# For Add Labels
for i,row in monthly_funded.iterrows():
    plt.text(i,row["loan_amount_millions"]+0.1,f"{row["loan_amount_millions"]:.2f}",
          ha="center" ,va="bottom",fontsize=9,rotation=0,color="black")

plt.title("Total Funded Amount by Month",fontsize=12,color="blue")
plt.xlabel("Month")
plt.ylabel("Funded Amount($ Millions)")
plt.grid(True,linestyle="--",alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Monthly Trends by Issue dtae for Total Amount Received

# %%
monthly_received=(
    df.sort_values("issue_date")
      .assign(month_name=lambda x: x["issue_date"].dt.strftime('%b %y'))
      .groupby("month_name",sort=False)["total_payment"]
      .sum() 
      .div(1000000)
      .reset_index(name="received_amount_millions")
    )
monthly_received
# Out:
#    month_name  received_amount_millions
# 0      Jan 21                 27.578836
# 1      Feb 21                 27.717745
# 2      Mar 21                 32.264400
# 3      Apr 21                 32.495533
# 4      May 21                 33.750523
# 5      Jun 21                 36.164533
# 6      Jul 21                 38.827220
# 7      Aug 21                 42.682218
# 8      Sep 21                 43.983948
# 9      Oct 21                 49.399567
# 10     Nov 21                 50.132030
# 11     Dec 21                 58.074380

# %%
plt.figure(figsize=(12,6))
# Plot for the area
plt.fill_between(monthly_received["month_name"],monthly_received["received_amount_millions"],color="yellow",alpha=0.5)
# Plot for the Line
plt.plot(monthly_received["month_name"],monthly_received["received_amount_millions"],color="purple",linewidth=2)


# For Add Labels
for i,row in monthly_received.iterrows():
    plt.text(i,row["received_amount_millions"]+0.1,f"{row["received_amount_millions"]:.2f}",
          ha="center" ,va="bottom",fontsize=9,rotation=0,color="black")

plt.title("Total receive Amount by Month",fontsize=12,color="green")
plt.xlabel("Month")
plt.ylabel("Received Amount($ Millions)")
plt.grid(True,linestyle="--",alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Monthly Trends by Issue Date for Total Loan Application

# %%
monthly_applications=(
    df.sort_values("issue_date")
      .assign(month_name=lambda x: x["issue_date"].dt.strftime('%b %y'))
      .groupby("month_name",sort=False)["id"]
      .count() 
      .reset_index(name="loan_applications_count")
    )
monthly_applications
# Out:
#    month_name  loan_applications_count
# 0      Jan 21                     2332
# 1      Feb 21                     2279
# 2      Mar 21                     2627
# 3      Apr 21                     2755
# 4      May 21                     2911
# 5      Jun 21                     3184
# 6      Jul 21                     3366
# 7      Aug 21                     3441
# 8      Sep 21                     3536
# 9      Oct 21                     3796
# 10     Nov 21                     4035
# 11     Dec 21                     4314

# %%
plt.figure(figsize=(12,6))
# Plot for the area
plt.fill_between(monthly_applications["month_name"],monthly_applications["loan_applications_count"],color="skyblue",alpha=0.5)
# Plot for the Line
plt.plot(monthly_applications["month_name"],monthly_applications["loan_applications_count"],color="orange",linewidth=2)


# For Add Labels
for i,row in monthly_applications.iterrows():
    plt.text(i,row["loan_applications_count"]+0.5,f"{row["loan_applications_count"]}",
          ha="center" ,va="bottom",fontsize=9,rotation=0,color="black")

plt.title("Total Loan Applications by Month",fontsize=12,color="red")
plt.xlabel("Month")
plt.ylabel("Number of Applications")
plt.grid(True,linestyle="--",alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State for Total Funded Amount

# %%
# First we have to create data
state_funding=df.groupby("address_state")["loan_amount"].sum().sort_values(ascending=True)
state_funding_thousands=state_funding/1000
state_funding_thousands
# Out:
# address_state
# ME        9.200
# NE       31.700
# IA       56.450
# ID       59.750
# IN       86.225
# MS      139.125
# TN      162.175
# VT      504.100
# SD      606.150
# MT      829.525
# WY      890.750
# AK     1031.800
# DE     1138.100
# WV     1830.525
# HI     1850.525
# RI     1883.025
# NM     1916.775
# NH     1917.900
# AR     2529.700
# DC     2652.350
# UT     2849.225
# KS     2872.325
# OK     3365.725
# KY     3504.100
# LA     4498.900
# OR     4720.150
# AL     4949.225
# WI     5070.450
# SC     5080.475
# NV     5307.375
# MN     6302.600
# MO     7151.175
# MI     7829.900
# CT     8435.575
# NC     8787.575
# WA     8855.525
# CO     8976.000
# AZ     9206.000
# MD    11911.400
# OH    12991.375
# MA    15051.000
# GA    15480.325
# PA    15826.525
# VA    15982.650
# IL    17124.225
# NJ    21657.475
# FL    30046.125
# TX    31236.650
# NY    42077.050
# CA    78484.125
# Name: loan_amount, dtype: float64

# %%
plt.figure(figsize=(10,8))
bars=plt.barh(state_funding_thousands.index,state_funding_thousands.values,color="lightgreen")

for bar in bars:
    width=bar.get_width()
    plt.text(width+10,bar.get_y() + bar.get_height() / 2,
                 f"{width:,.0f}k",va="center",fontsize=9)

                 
plt.title("Total Funded Amount by State (in Rs. Thousands)",color="red")
plt.xlabel("Funded Amount (Rs.\"000)")
plt.ylabel("State")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State for Total received Amount

# %%
# First we have to create data
state_amount_receive=df.groupby("address_state")["total_payment"].sum().sort_values(ascending=True)
state_amount_receive_thousands=state_amount_receive/1000
state_amount_receive_thousands
# Out:
# address_state
# ME       10.808
# NE       24.542
# IA       64.482
# ID       65.329
# IN       85.521
# TN      141.522
# MS      149.342
# VT      534.973
# SD      656.514
# MT      892.047
# WY     1046.050
# AK     1108.570
# DE     1269.136
# WV     1991.936
# RI     2001.774
# HI     2080.184
# NM     2084.485
# NH     2101.386
# AR     2777.875
# DC     2921.854
# UT     2952.412
# KS     3247.394
# OK     3712.649
# KY     3792.530
# OR     4966.903
# LA     5001.160
# NV     5451.443
# SC     5462.458
# WI     5485.161
# AL     5492.272
# MN     6750.746
# MO     7692.732
# MI     8543.660
# CT     9357.612
# WA     9531.739
# NC     9534.813
# CO     9845.810
# AZ    10041.986
# MD    12985.170
# OH    14330.148
# MA    16676.279
# GA    16728.040
# PA    17462.908
# VA    17711.443
# IL    18875.941
# NJ    23425.159
# FL    31601.905
# TX    34392.715
# NY    46108.181
# CA    83901.234
# Name: total_payment, dtype: float64

# %%
plt.figure(figsize=(10,8))
bars=plt.barh(state_amount_receive_thousands.index,state_amount_receive_thousands.values,color="yellow")

for bar in bars:
    width=bar.get_width()
    plt.text(width+10,bar.get_y() + bar.get_height() / 2,
                 f"{width:,.0f}k",va="center",fontsize=9)

                 
plt.title("Total Amount Receive by State (in Rs. Thousands)",color="red")
plt.xlabel("Amount receive (Rs.\"000)")
plt.ylabel("State")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State for Total Loan Application

# %%
# First we have to create data
state_Total_loan_application=df.groupby("address_state")["id"].count().sort_values(ascending=True)
state_Total_loan_application_thousands=state_Total_loan_application
state_Total_loan_application_thousands
# Out:
# address_state
# ME       3
# NE       5
# IA       5
# ID       6
# IN       9
# TN      17
# MS      19
# VT      54
# SD      63
# AK      78
# MT      79
# WY      79
# DE     110
# NH     161
# WV     167
# HI     170
# NM     183
# RI     196
# DC     214
# AR     236
# UT     252
# KS     260
# OK     293
# KY     320
# LA     426
# AL     432
# OR     436
# WI     446
# SC     464
# NV     482
# MN     592
# MO     660
# MI     685
# CT     730
# NC     759
# CO     770
# WA     805
# AZ     833
# MD    1027
# OH    1188
# MA    1310
# GA    1355
# VA    1375
# PA    1482
# IL    1486
# NJ    1822
# TX    2664
# FL    2773
# NY    3701
# CA    6894
# Name: id, dtype: int64

# %%
plt.figure(figsize=(10,8))
bars=plt.barh(state_Total_loan_application_thousands.index,state_Total_loan_application_thousands.values,color="pink")

for bar in bars:
    width=bar.get_width()
    plt.text(width+10,bar.get_y() + bar.get_height() / 2,
                 f"{width:,.0f}",va="center",fontsize=9)

                 
plt.title("Total Loan Application by State ",color="green")
plt.xlabel("Loan Application")
plt.ylabel("State")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Term Analysis by Total Funded Amount

# %%
term_funding_millions=df.groupby('term')["loan_amount"].sum()/1000000
term_funding_millions
# Out:
# term
# 36 months    273.041225
# 60 months    162.715850
# Name: loan_amount, dtype: float64

# %%
plt.figure(figsize=(5,5))
plt.pie(
    term_funding_millions,
    labels=term_funding_millions.index,
    autopct=lambda p:f"{p:.1f}%\n${p*sum(term_funding_millions)/100:.1f}M",
    startangle=90,
    wedgeprops={"width":0.4}
)
plt.gca().add_artist(plt.Circle((0,0),0.70,color="pink"))
plt.title("Total Funded Amount by Term (in $ Millions")
plt.show()

# %% [markdown]
# ### Loan Term Analysis by Total Amount Receive

# %%
term_amount_receive_millions=df.groupby('term')["total_payment"].sum()/1000000
term_amount_receive_millions
# Out:
# term
# 36 months    294.709458
# 60 months    178.361475
# Name: total_payment, dtype: float64

# %%
plt.figure(figsize=(5,5))
plt.pie(
   term_amount_receive_millions,
    labels=term_amount_receive_millions.index,
    autopct=lambda p:f"{p:.1f}%\n${p*sum(term_amount_receive_millions)/100:.1f}M",
    startangle=90,
    wedgeprops={"width":0.4}
)
plt.gca().add_artist(plt.Circle((0,0),0.70,color="green"))
plt.title("Total Amount Receive by Term (in $ Millions")
plt.show()

# %% [markdown]
# ### Loan Term Analysis by Total Loan Applications

# %%
term_toatal_loan_application=df.groupby('term')["id"].count()
term_toatal_loan_application
# Out:
# term
# 36 months    28237
# 60 months    10339
# Name: id, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.pie(
  term_toatal_loan_application,
    labels=term_toatal_loan_application.index,
    autopct=lambda p:f"{p:.1f}%\n${p*sum(term_toatal_loan_application)/100:.1f}",
    startangle=90,
    wedgeprops={"width":0.4}
)
plt.gca().add_artist(plt.Circle((0,0),0.70,color="yellow"))
plt.title("Total Amount Receive by Term (in $ Millions")
plt.show()

# %% [markdown]
# ### Employee Length by Total Funded Amount

# %%
emp_funding_thousands=df.groupby("emp_length")["loan_amount"].sum().sort_values()/1000

emp_funding_thousands
# Out:
# emp_length
# 9 years       15084.225
# 8 years       17558.950
# 7 years       20811.725
# 6 years       25612.650
# 1 year        32883.125
# 5 years       36973.625
# 4 years       37600.375
# 3 years       43937.850
# < 1 year      44210.625
# 2 years       44967.975
# 10+ years    116115.950
# Name: loan_amount, dtype: float64

# %%
plt.figure(figsize=(10,6))
bars=plt.barh(emp_funding_thousands.index,emp_funding_thousands.values,color="purple")

for bar in bars:
    width=bar.get_width()
    plt.text(width + 5 , bar.get_y() + bar.get_height()/2,
            f"Rs {width:,.0f}k",va="center",fontsize=9)

plt.title=("Total Funded Amount by Employment Length")
plt.xlabel("Funded Amount(Rs Thousands)")
plt.grid(linestyle="--")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Employee Length by Total Amount Received

# %%
emp_amount_receive_thousands=df.groupby("emp_length")["total_payment"].sum().sort_values()/1000

emp_amount_receive_thousands
# Out:
# emp_length
# 9 years       16516.173
# 8 years       19025.777
# 7 years       22584.136
# 6 years       27908.658
# 1 year        35498.348
# 5 years       40397.571
# 4 years       40964.850
# < 1 year      47545.011
# 3 years       47551.832
# 2 years       49206.961
# 10+ years    125871.616
# Name: total_payment, dtype: float64

# %%
plt.figure(figsize=(10,6))
bars=plt.barh(emp_amount_receive_thousands.index,emp_amount_receive_thousands.values,color="red")

for bar in bars:
    width=bar.get_width()
    plt.text(width + 5 , bar.get_y() + bar.get_height()/2,
            f"Rs {width:,.0f}k",va="center",fontsize=9)

plt.title=("Total Amount Receive by Employment Length")
plt.xlabel("Amount Receive (Rs Thousands)")
plt.grid(linestyle="--")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Employee Length by Total Loan Application

# %%
emp_total_loan_application=df.groupby("emp_length")["total_payment"].count().sort_values()

emp_total_loan_application
# Out:
# emp_length
# 9 years      1255
# 8 years      1476
# 7 years      1772
# 6 years      2228
# 1 year       3229
# 5 years      3273
# 4 years      3428
# 3 years      4088
# 2 years      4382
# < 1 year     4575
# 10+ years    8870
# Name: total_payment, dtype: int64

# %%
plt.figure(figsize=(10,6))
bars=plt.barh(emp_total_loan_application.index,emp_total_loan_application.values,color="skyblue")

for bar in bars:
    width=bar.get_width()
    plt.text(width + 5 , bar.get_y() + bar.get_height()/2,
            f"Rs {width:,.0f}",va="center",fontsize=9)

plt.title=("Total Loan Application by Employment Length")
plt.xlabel("Loan Applications")
plt.grid(linestyle="--")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose by Total Funded Amount

# %%
purpose_funding_millions=(df.groupby("purpose")["loan_amount"].sum().sort_values()/1000000)
purpose_funding_millions
# Out:
# purpose
# renewable_energy        0.845750
# vacation                1.967950
# educational             2.161650
# moving                  3.748125
# house                   4.824925
# medical                 5.533225
# wedding                 9.225800
# car                    10.223575
# major purchase         17.251600
# small business         24.123100
# other                  31.155750
# home improvement       33.350775
# credit card            58.885175
# Debt consolidation    232.459675
# Name: loan_amount, dtype: float64

# %%
plt.figure(figsize=(10,6))
bars=plt.barh(purpose_funding_millions.index,purpose_funding_millions.values,color="green")

for bar in bars:
    width=bar.get_width()
    plt.text(width + 5 , bar.get_y() + bar.get_height()/2,
            f"{width:,.2f}M",va="center",fontsize=12)

plt.title=("Total Funded Amount by Loan purpose")
plt.xlabel("Funded Amount(Rs Millions)")
plt.grid(linestyle="--")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose by Total Amount Receive

# %%
purpose_amount_receive_millions=(df.groupby("purpose")["total_payment"].sum().sort_values()/1000000)
purpose_amount_receive_millions
# Out:
# purpose
# renewable_energy        0.898931
# vacation                2.116738
# educational             2.248380
# moving                  3.999899
# house                   5.185538
# medical                 5.851372
# wedding                10.266856
# car                    11.324914
# major purchase         18.676927
# small business         23.814817
# other                  33.289676
# home improvement       36.380930
# credit card            65.214084
# Debt consolidation    253.801871
# Name: total_payment, dtype: float64

# %%
plt.figure(figsize=(10,6))
bars=plt.barh(purpose_amount_receive_millions.index,purpose_amount_receive_millions.values,color="pink")

for bar in bars:
    width=bar.get_width()
    plt.text(width + 5 , bar.get_y() + bar.get_height()/2,
            f"{width:,.2f}M",va="center",fontsize=12)

plt.title=("Total Amount Receive by Loan purpose")
plt.xlabel("Amount Receive (Rs Millions)")
plt.grid(linestyle="--")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose by Total Loan Applications

# %%
purpose_Total_loan_applications_millions=(df.groupby("purpose")["id"].count().sort_values())
purpose_Total_loan_applications_millions
# Out:
# purpose
# renewable_energy         94
# educational             315
# vacation                352
# house                   366
# moving                  559
# medical                 667
# wedding                 928
# car                    1497
# small business         1776
# major purchase         2110
# home improvement       2876
# other                  3824
# credit card            4998
# Debt consolidation    18214
# Name: id, dtype: int64

# %%
plt.figure(figsize=(10,6))
bars=plt.barh(purpose_Total_loan_applications_millions.index,purpose_Total_loan_applications_millions.values,color="blue")

for bar in bars:
    width=bar.get_width()
    plt.text(width + 5 , bar.get_y() + bar.get_height()/2,
            f"{width:,.0f}",va="center",fontsize=12)

plt.title=("Total Loan Application  by Loan purpose")
plt.xlabel("Loan Applications ")
plt.grid(linestyle="--")
plt.tight_layout()
plt.show()
